# %%
import matplotlib.pyplot as plt
import numpy
import keras
import sklearn
import json
# Out:
# Using TensorFlow backend.
# /Users/qiweili/anaconda/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
# %matplotlib inline

# %%
data0 = []
with open('data0.txt','r')as f:
    data0 = f.read()
data0 = json.loads(data0)
data0.keys()
# Out:
# dict_keys(['Ir_degrees', 'Pin_degrees', 'Ir_sensor', 'Pin_sensor'])

# %%
data1 = []
with open('data1.txt','r')as f:
    data1 = f.read()
data1 = json.loads(data1)
data1.keys()
# Out:
# dict_keys(['Ir_degrees', 'Ir_sensor', 'Pin_degrees', 'Pin_sensor'])

# %%
data2 = []
with open('data3.txt','r')as f:
    data2 = f.read()
data2 = json.loads(data2)
data2.keys()
# Out:
# dict_keys(['Ir_degrees', 'Pin_degrees', 'Ir_sensor', 'Pin_sensor'])

# %%
plt.plot(data0['Ir_sensor'],label='Ir')

# %%
plt.plot(data1['Ir_sensor'],label='Ir')
